# %%
import sys
import numpy as np
import re

# %%
sys.path.append('../')

# %%
from test_function_generator import GenerateFunctions

# %%
gf = GenerateFunctions(10000)

# %%
data = gf.generate_functions()
targets = gf.generate_test_functions()

# %%
data[:3]
# Out:
# ['\n\ndef dvlhfjo(qtherctg, ozjzrwmzj, yjfjbf, uu, pliu = False):\n    """\n    Comment\n    :test: dvlhfjo(44, 8, 47, 88) = False\n    """\n    return pliu',
#  '\n\ndef bhwodllq_blkgnbmixd_n(pewadkae, ipekjnrhze = False):\n    """\n    Comment\n    :test: bhwodllq_blkgnbmixd_n(24) is not True\n    """\n    return ipekjnrhze',
#  '\n\ndef yib_(dhcyp, va, elatrzbn, dme = True):\n    """\n    Comment\n    :test: yib_(91, 18, 75) is True\n    """\n    return dme']

# %%
targets[:3]
# Out:
# ['\n\n    def test_dvlhfjo(self):\n        self.assertFalse(dvlhfjo(44, 8, 47, 88))',
#  '\n\n    def test_bhwodllq_blkgnbmixd_n(self):\n        self.assertFalse(bhwodllq_blkgnbmixd_n(24))',
#  '\n\n    def test_yib_(self):\n        self.assertTrue(yib_(91, 18, 75))']

# %%
def extract_intent(x):
    return re.search(r'^\s+:test:\s+(.*)$', x, re.MULTILINE).group(1)

# %%
intents = [extract_intent(x) for x in data]

# %%
intents[:3]
# Out:
# ['dvlhfjo(44, 8, 47, 88) = False',
#  'bhwodllq_blkgnbmixd_n(24) is not True',
#  'yib_(91, 18, 75) is True']

# %%
# start and end char
targets = ['$' + x + '¤' for x in targets]

# %% [markdown]
# ### Vectorize data

# %%
input_characters = sorted(list(set([x for line in intents for x in line])))
target_characters = sorted(list(set([x for line in targets for x in line])))

# %%
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)

# %%
max_encoder_seq_length = max([len(txt) for txt in intents])
max_decoder_seq_length = max([len(txt) for txt in targets])

# %%
input_token_index = {char:i for i,char in enumerate(input_characters)}
target_token_index = {char:i for i,char in enumerate(target_characters)}

# %%
encoder_input_data = np.zeros((len(intents), max_encoder_seq_length, num_encoder_tokens), dtype='float32')
decoder_input_data = np.zeros((len(targets), max_decoder_seq_length, num_decoder_tokens), dtype='float32')
decoder_target_data = np.zeros((len(intents), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(intents, targets)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# %%
latent_dim = 256

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

# %%
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 45)     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 50)     0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 309248      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 256),  314368      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 50)     12850       lstm_1[0][0]
# ==================================================================================================
# Total params: 636,466
# Trainable params: 636,466
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size=16, epochs=100, validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 262s 33ms/step - loss: 1.2523 - val_loss: 0.8792
# Epoch 2/100
# 8000/8000 [==============================] - 271s 34ms/step - loss: 0.8480 - val_loss: 0.8346
# Epoch 4/100
# 8000/8000 [==============================] - 275s 34ms/step - loss: 0.8246 - val_loss: 0.8199
# Epoch 8/100
# 8000/8000 [==============================] - 275s 34ms/step - loss: 0.8114 - val_loss: 0.8111
# Epoch 13/100
# 6944/8000 [=========================>....] - ETA: 35s - loss: 0.7983

# %%
model.save('../models/s2s.h5')
# Out:
# WARNING:tensorflow:Layer lstm_5 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_4/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_4/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).

# %% [markdown]
# ## Inference

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h , state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
reverse_input_char_index = {i:char for char, i in input_token_index.items()}
reverse_target_char_index = {i:char for char, i in target_token_index.items()}

# %%
reverse_target_char_index
# Out:
# {0: '\n',
#  1: ' ',
#  2: '$',
#  3: '(',
#  4: ')',
#  5: ',',
#  6: '.',
#  7: '0',
#  8: '1',
#  9: '2',
#  10: '3',
#  11: '4',
#  12: '5',
#  13: '6',
#  14: '7',
#  15: '8',
#  16: '9',
#  17: ':',
#  18: 'A',
#  19: 'D',
#  20: 'E',
#  21: 'F',
#  22: 'N',
#  23: 'R',
#  24: 'S',
#  25: 'T',
#  26: '_',
#  27: 'a',
#  28: 'b',
#  29: 'c',
#  30: 'd',
#  31: 'e',
#  32: 'f',
#  33: 'g',
#  34: 'h',
#  35: 'i',
#  36: 'j',
#  37: 'k',
#  38: 'l',
#  39: 'm',
#  40: 'n',
#  41: 'o',
#  42: 'p',
#  43: 'q',
#  44: 'r',
#  45: 's',
#  46: 't',
#  47: 'u',
#  48: 'v',
#  49: 'w',
#  50: 'x',
#  51: 'y',
#  52: 'z',
#  53: '¤'}

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0,0,target_token_index['$']] = 1.
    
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char
        
        #exit
        if (sampled_char == '¤' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True
        
        target_seq = np.zeros((1,1, num_decoder_tokens))
        target_seq[0,0,sampled_token_index] = 1.
        
        states_value = [h,c]
    return decoded_sentence

# %%
for seq_index in range(100):
    input_seq = encoder_input_data[seq_index: seq_index+1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', intents[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: dmjcfy_cva(38, 63, 24, 7) = True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ijhl__k_(86, 32) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: mopfyk_er_lon_rltr_(63) = 62
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: rj___f_fwxpcz_hb_k(65, 10, 61, 84, 86) = 27
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: gnybehjvbjnvok__(79, 100, 98, 72, 83) = True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ht_bgc_zph_mwhb_vupfw(4, 36, 4) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ywgaz(44, 87, 97) is not 0
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: nv_lices_tktrvgftg(46, 57, 31, 85) is not False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: l_iryhal__e(80) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: w____p(66) is False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: kzaay(19, 24) != 0
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lo__ekapamou__hauxby(90) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: mdiqvejcum_vaebdgbe(22, 18, 35, 54, 15) = True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ha_ox__szuyev(95) is not False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: w_acndtehlrt_yj(14, 96) = True
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: pta(11, 57) is not False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: i_ptzfv_kuoxcpzzo(96, 13) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: pxktgu_azgrvqu__csn_(22, 17, 50) is 75
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: wztfn_fgybnh_zeq(32, 47, 35, 81, 67) is not 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lp_vmis(66, 40, 54, 15, 89) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: yur_pg(80, 12, 100, 41, 73) is False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: hvdjwu__mu_(51, 31, 57, 38) is not 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: gsgqspp(21, 34, 43) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ogeuum_savfmapu_(11) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: vitdgaw_ft(32) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: dr_lwmb(34, 86, 86, 31, 53) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: tvu_qksjgk_w(38, 56, 40) = True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: uhztgpnb(89, 81, 67, 2) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: yaxdlfo_usv_(99, 1, 51, 73) is 59
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: gz_z_mrb(61) is not 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: wib(57, 84, 9) != True
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: yxinaib(96) is True
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: dhmbqpgmthjqbb(88) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: n__crs_his_wzp_s(24, 85, 92) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lheynk_d(48, 80, 21, 33) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: y__dps(68, 21, 4) != False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: f_ldgg(0) != False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: tcf_viufjy_s_rityyb(31, 30, 99, 69) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: yxy_jgm(29) != 0
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: cg__hvv_bsi(95, 74, 84, 45) is 27
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: e_bwxuxwgypz(38) is not False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lgxppe_ytm(99) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: sb_scl_uqdo_yjdw(59, 72, 29, 40) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: mw_yz__urdiajreps(75, 26, 90) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: hqueadwkeg_r_aer(69, 43) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: sxz_ptu_clih_i(66, 84, 3) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ljdtqzaps(85) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ablttzkuebt__y(70, 53, 8, 80) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: al_cthco_m(52, 10, 57) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: snyyu_zua_otz_(58, 84) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: v_vzwk(84, 52, 12, 42) is not 0
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ogl__cpf_zgk_qns___(4) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: fizu___ql_lkyoy_lm_(98, 7, 13, 28) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: fjkau_tek(31, 16, 79, 83, 61) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: h_yuclnntuuadnp(98, 86, 74, 42, 28) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: uvfzvgvunagk_(56, 52, 1, 49, 49) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: wplkegl_v(97) != False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: w__yjuhtd__(28, 0, 76, 26, 79) is False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: wafuechy(36, 37) is 19
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ef_(14) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: vmmbqg_fooettunmm(17, 14, 22, 70) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: nef(93) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: beu_qzvfaqc_poy(38, 97, 77) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: kf_k(66, 99) is not True
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: crh_gwsc__u_qxhczm_u(8) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: dw_rebhbewmbnh(1, 18, 19, 28) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: egmwl_ct_(19, 18, 56, 66) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: o_bx__m__rb___njfqn(70) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: neqidm_j_crf_zlv(96, 10, 79) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: k_x(9, 96, 14) != True
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lvxrsgvzt_fc__u_(60) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: tfsz_ytc_hh_am(75, 67) is 27
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: kuus_b_(92, 36, 81) = False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: rqhc_vnlzovsl(64, 1, 58) is not False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: g_x_aylhzbhca(77, 59) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: fzf_uqf_t_k_hu_ek(61, 86, 5, 92) is not False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: qc_le_brfksi(32, 34, 45, 60) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: hdpwyh__nhfm(20, 26, 47, 63, 22) = 88
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: pwe_set(50, 91, 60, 3) is 30
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: tmwyw_iw_vgsfrvvrtib(98, 58) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: btpx_asfthyf_a_yz_v(68, 67, 86, 7) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: zkgo_oa__yytpvhkar(15, 39) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: toscvpm__in_vxhy(5, 25, 97) is True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: t_dx_j(62) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: g_vbthhrljskbvefmg(97) is not 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: s_v_ezk_ee__w_dqu_tk(50) = True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: o_tsv_h_qmisbhi_lm(88, 58, 77, 28, 98) != 0
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ndbwbg(58, 98, 37, 20, 73) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: khcjiihxh_gbjhrxdehfe(87, 79) = False
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: eqotf_jamtsc_ltub_(31) is 84
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ytzaptthtjcjdw(29, 19) != 0
# Decoded sentence: START
#
#          tttt_________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: imceexe_(95, 89) != True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: mxewc_s_t(27, 30, 12) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: tgmh(94, 97, 84, 81, 8) is not True
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ezvqdjndzcs(99, 0, 65, 59) = 33
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: uh_zr_(36, 17, 16, 93) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: mae_nliy_u(15) = False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: las(63, 27) != False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: ijcv_wudtt__q(18, 39) is False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_
# -
# Input sentence: lloi_mhit__s(99) != False
# Decoded sentence: START
#
#
#          tttt________________lf            ssssesertrtttte(((____________________,,,                seesertttttt_

# %%
np.shape(encoder_input_data[0:1])
# Out:
# (1, 47, 45)

# %%
intents[0]
# Out:
# 'dmjcfy_cva(38, 63, 24, 7) = True'
